# %%
import snowflake.connector as snow

# Create a connection to Snowflake
connection = snow.connect(
    account="xjb25065.us-east-1",
    user="my_user_name",
    password="my_password",
    # url="my_url",
)

# Define a cursor
cursor = connection.cursor()

try:
    # Execute a SQL query against Snowflake to get the current_version
    cursor.execute("SELECT current_version()")
    one_row = cursor.fetchone()

    # Display the version information
    print(one_row[0])
finally:
    cursor.close()
connection.close()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/util/connection.py:79, in create_connection(address, timeout, source_address, socket_options)
#      75     return six.raise_from(
#      76         LocationParseError(u"'%s', label empty or too long" % host), None
#      77     )
# ---> 79 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      80     af, socktype, proto, canonname, sa = res
#
# File /usr/lib/python3.8/socket.py:918, in getaddrinfo(host, port, family, type, proto, flags)
#     917 addrlist = []
# --> 918 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:1058, in HTTPSConnectionPool._validate_conn(self, conn)
#    1057 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1058     conn.connect()
#    1060 if not conn.is_verified:
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <snowflake.connector.vendored.urllib3.connection.HTTPSConnection object at 0x7f47a214c280>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:827, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     824     log.warning(
#     825         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     826     )
# --> 827     return self.urlopen(
#     828         method,
#     829         url,
#     830         body,
#     831         headers,
#     832         retries,
#     833         redirect,
#     834         assert_same_host,
#     835         timeout=timeout,
#     836         pool_timeout=pool_timeout,
#     837         release_conn=release_conn,
#     838         chunked=chunked,
#     839         body_pos=body_pos,
#     840         **response_kw
#     841     )
#     843 # Handle redirect?
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:799, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     797     e = ProtocolError("Connection aborted.", e)
# --> 799 retries = retries.increment(
#     800     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     801 )
#     802 retries.sleep()
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='xjb25065.us-east-1.snowflakecomputing.com', port=443): Max retries exceeded with url: /session/v1/login-request?request_id=4c790115-e9cd-425f-8db8-bd073daaddc9&request_guid=891e96ff-8435-4867-84bf-1a15b57da12d (Caused by NewConnectionError('<snowflake.connector.vendored.urllib3.connection.HTTPSConnection object at 0x7f47a214c280>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/network.py:1082, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1079 # socket timeout is constant. You should be able to receive
#    1080 # the response within the time. If not, ConnectReadTimeout or
#    1081 # ReadTimeout is raised.
# -> 1082 raw_ret = session.request(
#    1083     method=method,
#    1084     url=full_url,
#    1085     headers=headers,
#    1086     data=input_data,
#    1087     timeout=socket_timeout,
#    1088     verify=True,
#    1089     stream=is_raw_binary,
#    1090     auth=SnowflakeAuth(token),
#    1091 )
#    1092 download_end_time = get_time_millis()
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/vendored/requests/adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='xjb25065.us-east-1.snowflakecomputing.com', port=443): Max retries exceeded with url: /session/v1/login-request?request_id=4c790115-e9cd-425f-8db8-bd073daaddc9&request_guid=891e96ff-8435-4867-84bf-1a15b57da12d (Caused by NewConnectionError('<snowflake.connector.vendored.urllib3.connection.HTTPSConnection object at 0x7f47a214c280>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/connection.py:1452, in SnowflakeConnection._authenticate(self, auth_instance)
#    1451 try:
# -> 1452     auth.authenticate(
#    1453         auth_instance=auth_instance,
#    1454         account=self.account,
#    1455         user=self.user,
#    1456         database=self.database,
#    1457         schema=self.schema,
#    1458         warehouse=self.warehouse,
#    1459         role=self.role,
#    1460         passcode=self._passcode,
#    1461         passcode_in_password=self._passcode_in_password,
#    1462         mfa_callback=self._mfa_callback,
#    1463         password_callback=self._password_callback,
#    1464         session_parameters=self._session_parameters,
#    1465     )
#    1466 except OperationalError as e:
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/auth/_auth.py:270, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     269 try:
# --> 270     ret = self._rest._post_request(
#     271         url,
#     272         headers,
#     273         json.dumps(body),
#     274         socket_timeout=auth_instance._socket_timeout,
#     275     )
#     276 except ForbiddenError as err:
#     277     # HTTP 403
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/network.py:750, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, socket_timeout, _no_results, no_retry, _include_retry_params)
#     748     pprint(ret)
# --> 750 ret = self.fetch(
#     751     "post",
#     752     full_url,
#     753     headers,
#     754     data=body,
#     755     timeout=timeout,
#     756     token=token,
#     757     no_retry=no_retry,
#     758     _include_retry_params=_include_retry_params,
#     759     socket_timeout=socket_timeout,
#     760 )
#     761 logger.debug(
#     762     "ret[code] = {code}, after post request".format(
#     763         code=(ret.get("code", "N/A"))
#     764     )
#     765 )
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/network.py:865, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     864 while True:
# --> 865     ret = self._request_exec_wrapper(
#     866         session, method, full_url, headers, data, retry_ctx, **kwargs
#     867     )
#     868     if ret is not None:
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/network.py:993, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     990 if (
#     991     raise_raw_http_failure and isinstance(e, requests.exceptions.HTTPError)
#     992 ) or not no_retry:
# --> 993     raise e
#     994 logger.debug("Ignored error", exc_info=True)
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/network.py:915, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     914 try:
# --> 915     return_object = self._request_exec(
#     916         session=session,
#     917         method=method,
#     918         full_url=full_url,
#     919         headers=headers,
#     920         data=data,
#     921         token=token,
#     922         raise_raw_http_failure=raise_raw_http_failure,
#     923         **kwargs,
#     924     )
#     925     if return_object is not None:
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/network.py:1180, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1175     logger.debug(
#    1176         "Hit a timeout error while logging in. Will be handled by "
#    1177         f"authenticator. Ignore the following. Error stack: {err}",
#    1178         exc_info=True,
#    1179     )
# -> 1180     raise OperationalError(
#    1181         msg="ConnectionTimeout occurred during login. Will be handled by authenticator",
#    1182         errno=ER_CONNECTION_TIMEOUT,
#    1183     )
#    1184 else:
#
# OperationalError: 251011: ConnectionTimeout occurred during login. Will be handled by authenticator
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 4
#       1 import snowflake.connector as snow
#       3 # Create a connection to Snowflake
# ----> 4 connection = snow.connect(
#       5     account="xjb25065.us-east-1",
#       6     user="my_user_name",
#       7     password="my_password",
#       8     # url="my_url",
#       9 )
#      11 # Define a cursor
#      12 cursor = connection.cursor()
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/__init__.py:55, in Connect(**kwargs)
#      53 @wraps(SnowflakeConnection.__init__)
#      54 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 55     return SnowflakeConnection(**kwargs)
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/connection.py:466, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
#     464     kwargs = _get_default_connection_params()
#     465 self.__set_error_attributes()
# --> 466 self.connect(**kwargs)
#     467 self._telemetry = TelemetryClient(self._rest)
#     468 self.expired = False
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/connection.py:793, in SnowflakeConnection.connect(self, **kwargs)
#     791             raise Exception(str(exceptions_dict))
#     792 else:
# --> 793     self.__open_connection()
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/connection.py:1124, in SnowflakeConnection.__open_connection(self)
#    1116 else:
#    1117     # okta URL, e.g., https://<account>.okta.com/
#    1118     self.auth_class = AuthByOkta(
#    1119         application=self.application,
#    1120         timeout=self.login_timeout,
#    1121         backoff_generator=self._backoff_generator,
#    1122     )
# -> 1124 self.authenticate_with_retry(self.auth_class)
#    1126 self._password = None  # ensure password won't persist
#    1127 self.auth_class.reset_secrets()
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/connection.py:1424, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1421 def authenticate_with_retry(self, auth_instance) -> None:
#    1422     # make some changes if needed before real __authenticate
#    1423     try:
# -> 1424         self._authenticate(auth_instance)
#    1425     except ReauthenticationRequest as ex:
#    1426         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1427         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/connection.py:1498, in SnowflakeConnection._authenticate(self, auth_instance)
#    1496     if _CONNECTIVITY_ERR_MSG in e.msg:
#    1497         auth_op.msg += f"\n{_CONNECTIVITY_ERR_MSG}"
# -> 1498     raise auth_op from e
#    1499 logger.debug("Continuing authenticator specific timeout handling")
#    1500 continue
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/connection.py:1473, in SnowflakeConnection._authenticate(self, auth_instance)
#    1471 while True:
#    1472     try:
# -> 1473         auth_instance.handle_timeout(
#    1474             authenticator=self._authenticator,
#    1475             service_name=self.service_name,
#    1476             account=self.account,
#    1477             user=self.user,
#    1478             password=self._password,
#    1479         )
#    1480         auth.authenticate(
#    1481             auth_instance=auth_instance,
#    1482             account=self.account,
#    (...)
#    1492             session_parameters=self._session_parameters,
#    1493         )
#    1494     except OperationalError as auth_op:
#
# File ~/.local/lib/python3.8/site-packages/snowflake/connector/auth/by_plugin.py:214, in AuthByPlugin.handle_timeout(***failed resolving arguments***)
#     208 if not self._retry_ctx.should_retry:
#     209     error = OperationalError(
#     210         msg=f"Could not connect to Snowflake backend after {self._retry_ctx.current_retry_count + 1} attempt(s)."
#     211         "Aborting",
#     212         errno=ER_FAILED_TO_CONNECT_TO_DB,
#     213     )
# --> 214     raise error
#     215 else:
#     216     logger.debug(
#     217         f"Hit connection timeout, attempt number {self._retry_ctx.current_retry_count + 1}."
#     218         " Will retry in a bit..."
#     219     )
#
# OperationalError: 250001: Could not connect to Snowflake backend after 2 attempt(s).Aborting
